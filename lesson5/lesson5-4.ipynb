# %%
import random
import time
for i in range(10):
    print(random.randint(1,10))
    time.sleep(1) # sleep for a random amount of time
# Out:
# 1
# 6
# 4
# 2
# 7
# 7
# 2
# 3
# 1
# 4

# %%
import random
import time

for i in range(100):
    print(random.randint(1,10))
    time.sleep(1)

# %%
import requests # pip install requests
r=requests.get('https://api.github.com/events') #requests.models.Response
type(r)
# Out:
# requests.models.Response

# %%
r.text
# Out:
# '[{"id":"41926730043","type":"WatchEvent","actor":{"id":181551004,"login":"hust09lp","display_login":"hust09lp","gravatar_id":"","url":"https://api.github.com/users/hust09lp","avatar_url":"https://avatars.githubusercontent.com/u/181551004?"},"repo":{"id":695471096,"name":"ivaquero/book-control","url":"https://api.github.com/repos/ivaquero/book-control"},"payload":{"action":"started"},"public":true,"created_at":"2024-09-14T07:39:31Z"},{"id":"41926730031","type":"PushEvent","actor":{"id":166895733,"login":"swa-runner-app[bot]","display_login":"swa-runner-app","gravatar_id":"","url":"https://api.github.com/users/swa-runner-app[bot]","avatar_url":"https://avatars.githubusercontent.com/u/166895733?"},"repo":{"id":857267324,"name":"static-web-apps-testing-org/swa0a792d3b85924d9fa317eed74aebd2fa","url":"https://api.github.com/repos/static-web-apps-testing-org/swa0a792d3b85924d9fa317eed74aebd2fa"},"payload":{"repository_id":857267324,"push_id":20235273551,"size":1,"distinct_size":1,"ref":"re
# ...
